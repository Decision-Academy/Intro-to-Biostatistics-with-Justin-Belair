# %%
import pandas as pd

sample_data_py = pd.read_csv("session_3_hw_data.csv")
print(sample_data_py.head())

print(sample_data_py["0"].mean())
print(sample_data_py["0"].median())
print(sample_data_py["0"].std(ddof=1))

percentiles = [0.01, 0.03, 0.25, 0.5, 0.75, 0.95, 0.99]
print(sample_data_py["0"].quantile(percentiles))

# %%
import numpy as np

rolls_p = 10000
die1_p = np.random.randint(1, 7, rolls_p)
die2_p = np.random.randint(1, 7, rolls_p)
sums_p = die1_p + die2_p
